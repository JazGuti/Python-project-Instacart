# %% [markdown]
# # Exercise 4.7

# %% [markdown]
# 1. import libraires and data
# 2. create subset
# 3. Create if statement for price range
# 4. Create if statment loc() for price range
# 5. For loop statment orders day of week
# 6. Checking counts for new column
#
# Task 4.7
# 1. (recheck steps in exercise)
# 2. Creating forloop statement for busiest days & slowest days
# 3. Check values for accuracy
# 4. Creating a new column for busiest hours of the day
# 5. Print frequency
# 6. Check Task
# 7. Export

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/jazmingutierrez/DEC2023 Instacart Basket Analysis'

# %%
#import data
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merge.pkl'))

# %% [markdown]
# ## Creating subset

# %%
# create subset
df = df_ords_prods_merge[:1000000]

# %%
# check subset
df.shape
# Out:
# (1000000, 14)

# %% [markdown]
# ## Creating if stament with user-defined for price_range

# %%
# Define a function 
def price_label(row):
    if row ['prices'] <=5:
        return 'Low range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid range product'
    elif row ['prices'] > 15:
        return 'High range products'
    else: return np.nan

# %%
# Apply the function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/0l/qkdwcw1x7353qnj1307cr7x00000gn/T/ipykernel_85594/902492192.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %% [markdown]
# ## Creating if statement with loc() for price_range

# %%
# printing price_range
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid range product    756450
# Low range product    243550
# Name: count, dtype: int64

# %%
# checking max price
df['prices'].max()
# Out:
# 14.8

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['prices'] <= 15) & (df_ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <=5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21890146
# Low-range product     10126384
# High-range product      417682
# Name: count, dtype: int64

# %% [markdown]
# ## Foorloop statements

# %%
# Finding which days most orders take place 
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: count, dtype: int64

# %% [markdown]
# 0= Saturday which is the busiest day, 4= Wednesday is least busy,

# %%
# Create a new column for busiest, least, and regular days
result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
# Checking results
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Create new column
df_ords_prods_merge['busiest_day'] = result

# %% [markdown]
# ## Checking counts

# %%
df_ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: count, dtype: int64

# %%
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: count, dtype: int64

# %% [markdown]
# # Task 4.7

# %% [markdown]
# ## 2. Creating forloop statement for busiest days & slowest days

# %%
# Checking for busiest and slowest days
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: count, dtype: int64

# %% [markdown]
# Busiest days: 0=Saturday, 1=Sunday;  Slowest Days: 3=Tuesday, 4=Wednesday

# %%
# Create a new column for Busiest and Slowest days
result_2 = []
for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0 or value ==1:
    result_2.append("Busiest days")
  elif value == 4 or value ==3:
    result_2.append("Least busiest days")
  else:
    result_2.append("Regularly busy")

# %%
# Checking results
result_2
# Out:
# ['Regularly busy',
#  'Least busiest days',
#  'Least busiest days',
#  'Least busiest days',
#  'Least busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Least busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busiest days',
#  'Least busiest days',
#  'Least busiest days',
#  'Least busiest days',
#  'Least busiest days',
#  'Least busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busiest days',
#  'Regularly busy',
#  'Least busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Least busiest days',
#  'Least busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
# ...

# %% [markdown]
# ## 3. Check values for accuracy

# %%
# Create new column to see result_2
df_ords_prods_merge['Busiest_days'] = result_2

# %%
# Check counts 
df_ords_prods_merge['Busiest_days'].value_counts(dropna = False)
# Out:
# Busiest_days
# Regularly busy        12927461
# Busiest days          11875462
# Least busiest days     7631289
# Name: count, dtype: int64

# %%
# Check counts for busiest_day
df_ords_prods_merge['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: count, dtype: int64

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  time_of_day  \
# 0   2539329        1             1                   2            8
# 1   2398795        1             2                   3            7
# 2    473747        1             3                   3           12
# 3   2254736        1             4                   4            7
# 4    431534        1             5                   4           15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %% [markdown]
# Busiest days and least busiest days amount of days did increase in result_2 "Busiest days" column, Regularly busy days decreased in result_2 when comparing to result "Busiest day" column.

# %% [markdown]
# ## 4. Creating a new column for busiest hours of the day

# %%
# printing time_of_day
df['time_of_day'].value_counts(dropna = False)
# Out:
# time_of_day
# 10    90492
# 11    85835
# 9     84211
# 14    81965
# 15    81388
# 13    81377
# 12    79248
# 16    76499
# 17    60697
# 8     57772
# 18    46755
# 19    35989
# 7     29181
# 20    28213
# 21    23796
# 22    19103
# 23    11911
# 6      8827
# 0      6451
# 1      3163
# 5      2552
# 2      1865
# 4      1427
# 3      1283
# Name: count, dtype: int64

# %% [markdown]
# "Most orders"= 10, 11, 9, 14, 15, 13, 12, 16
# "Average orders" = 17, 8, 18, 19, 7, 20, 21, 22
# "Fewest orders" = 23, 6, 0, 1, 5, 2, 4, 3

# %%
# Create column for time of day with most to fewest orders
result_3 = []

for value in df_ords_prods_merge["time_of_day"]:
    if value in [10, 11, 9, 14, 15, 13, 12, 16]:
        result_3.append("Most orders")
    elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
        result_3.append("Fewest orders")
    else:
        result_3.append("Average orders")

# %%
#Checking results
result_3
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
# Create column "busiest_period_of_day"
df_ords_prods_merge['busiest_period_of_day'] = result_3

# %% [markdown]
# ## 5. Print frequency

# %%
df_ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       21137262
# Average orders    10006752
# Fewest orders      1290198
# Name: count, dtype: int64

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  time_of_day  \
# 0   2539329        1             1                   2            8
# 1   2398795        1             2                   3            7
# 2    473747        1             3                   3           12
# 3   2254736        1             4                   4            7
# 4    431534        1             5                   4           15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %% [markdown]
# ## 7. Export as pkl

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merge_deriving_variables.pkl'))
